# %% [markdown]
# <a href="https://colab.research.google.com/github/guillesg01/Algoritmos_de_Optimizacion_Guillermo_Sanchez/blob/main/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = [1,2,6,7,12,13]

B = [2,3,4,7,13]
C = []
for i in range(len(A)):
  if ( A[i] in B):
    C.append(A[i])
print(C)
# Out:
# [2, 7, 13]
